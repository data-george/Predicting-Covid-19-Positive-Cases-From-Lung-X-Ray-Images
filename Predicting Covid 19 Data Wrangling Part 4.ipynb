# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.3.0

# %%
import keras
from keras import backend as K

print('Keras version:',keras.__version__)
# Out:
# Keras version: 2.4.3

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from keras.preprocessing.image import ImageDataGenerator

# Recall that the images were moved to a folder names XRays. 
training_folder_name = '/gdrive/My Drive/XRays'

# The folder contains a subfolder for each class of shape
classes = sorted(os.listdir(training_folder_name))
print(classes)

# Our source images are 1024 x 1024
image_size = (1024,1024)
batch_size = 32

print("Getting Data...")
datagen = ImageDataGenerator(rescale=1./255, # normalize pixel values for all 
                                             # the images, 1 color channel
                             validation_split=0.1) # hold back 10% of the images 
                                                   # for validation
                                                   # we are increasing the training 
                                                   # size since we don't have
                                                   # too many Covid images

print("Preparing training dataset...")
train_generator = datagen.flow_from_directory(
    training_folder_name,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training') # set as training data

print("Preparing validation dataset...")
validation_generator = datagen.flow_from_directory(
    training_folder_name,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation') # set as validation data
# Out:
# ['COVID-19', 'Normal', 'Viral Pneumonia']
# Getting Data...
# Preparing training dataset...
# Found 2616 images belonging to 3 classes.
# Preparing validation dataset...
# Found 289 images belonging to 3 classes.
